# %% [markdown]
# # 3 Exploratory Data Analysis (EDA)

# %% [markdown]
# ## 3.1 Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
sns.set()

# %% [markdown]
# ## 3.2 Load The 'Olist' E-Commerce Dataset

# %%
orders17 = pd.read_csv(r'C:\Users\JIYOON JUNG\Desktop\Springboard\Unit 15 Data Wrangling\Capstone2\Brazilian E-Commerce Public Dataset by Olist\order17')

# %%
orders17.shape
# Out:
# (45482, 33)

# %%
orders17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45482 entries, 0 to 45481
# Data columns (total 33 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       45482 non-null  object
#  1   customer_id                    45482 non-null  object
#  2   order_status                   45482 non-null  object
#  3   order_purchase_timestamp       45482 non-null  object
#  4   order_approved_at              45469 non-null  object
#  5   order_delivered_carrier_date   44873 non-null  object
#  6   order_delivered_customer_date  44345 non-null  object
#  7   order_estimated_delivery_date  45482 non-null  object
#  8   product_id                     45482 non-null  object
#  9   seller_id                      45482 non-null  object
#  10  shipping_limit_date            45482 non-null  object
#  11  price                          45482 non-null  float64
#  12  freight_value                  45482 non-null  float64
#  13  customer_unique_id             45482 non-null  object
#  14  customer_zip_code_prefix       45482 non-null  int64
#  15  customer_city                  45482 non-null  object
#  16  customer_state                 45482 non-null  object
#  17  product_category_name          45482 non-null  object
#  18  product_name_lenght            45482 non-null  float64
#  19  product_description_lenght     45482 non-null  float64
#  20  product_photos_qty             45482 non-null  float64
#  21  product_weight_g               45481 non-null  float64
#  22  product_length_cm              45481 non-null  float64
#  23  product_height_cm              45481 non-null  float64
#  24  product_width_cm               45481 non-null  float64
#  25  seller_zip_code_prefix         45482 non-null  float64
#  26  seller_city                    45482 non-null  object
#  27  seller_state                   45482 non-null  object
#  28  product_category_name_english  45482 non-null  object
#  29  Year                           45482 non-null  int64
#  30  Month                          45482 non-null  int64
#  31  order_item_qty                 45482 non-null  int64
#  32  product_qty                    45482 non-null  int64
# dtypes: float64(10), int64(5), object(18)
# memory usage: 11.5+ MB

# %%
orders17.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  6ea2f835b4556291ffdc53fa0b3b95e8  c7340080e394356141681bd4c9b8fe31
# 2  82bce245b1c9148f8d19a55b9ff70644  388025bec8128ff20ec1a316ed4dcf02
# 3  af5b0604e113e1526593d505a26ef39d  b896b244963dc7543d400ad82d6710e0
# 4  1c35ac660d7ef6691b25d20df3d6eccb  68c85132eb3b96fbe6cbddc09a568d24
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2017-11-24 21:27:48  2017-11-25 00:21:09
# 2    delivered      2017-04-20 17:15:46  2017-04-21 05:15:56
# 3    delivered      2017-09-27 12:07:22  2017-09-27 12:26:02
# 4    delivered      2017-06-27 23:11:57  2017-06-27 23:35:09
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2017-12-13 21:14:05           2017-12-28 18:59:23
# 2          2017-04-24 09:34:13           2017-05-10 09:17:55
# 3          2017-09-29 22:25:42           2017-09-30 17:13:01
# 4          2017-06-28 14:28:00           2017-06-29 10:16:35
#
#   order_estimated_delivery_date                        product_id  \
# 0                    2017-10-18  87285b34884572647811a353c7ac498a
# 1                    2017-12-21  be021417a6acb56b9b50d3fd2714baa8
# 2                    2017-05-12  a5a0e71a81ae65aa335e71c06261e260
# 3                    2017-10-16  978859c6048ded0fa8bf3b9ea8236387
# 4                    2017-07-10  42a2c92a0979a949ca4ea89ec5c7b934
#
#                           seller_id  ... product_height_cm  product_width_cm  \
# 0  3504c0cb71d7fa48d967e0e4c94d59d9  ...               8.0              13.0
# 1  f5f46307a4d15880ca14fab4ad9dfc9b  ...              34.0              34.0
# 2  c8417879a15366a17c30af34c798c332  ...              22.0              28.0
# 3  813348c996469b40f2e028d5429d3495  ...               4.0              20.0
# 4  813348c996469b40f2e028d5429d3495  ...              47.0              27.0
#
#    seller_zip_code_prefix seller_city  seller_state  \
# 0                  9350.0        maua            SP
# 1                 89165.0  rio do sul            SC
# 2                  4445.0   sao paulo            SP
# 3                 13206.0     jundiai            SP
# 4                 13206.0     jundiai            SP
#
#   product_category_name_english  Year Month  order_item_qty  product_qty
# 0                    housewares  2017    10               1            1
# 1                    housewares  2017    11               1            1
# 2                    housewares  2017     4               5            5
# 3                    housewares  2017     9               1            1
# 4                    housewares  2017     6               1            1
#
# [5 rows x 33 columns]

# %% [markdown]
# ## 3.3 Explore The Data

# %%
orders17.describe().T
# Out:
#                               count          mean           std     min  \
# price                       45482.0    124.621989    190.512957     1.2
# freight_value               45482.0     19.538062     14.495322     0.0
# customer_zip_code_prefix    45482.0  36326.248604  29817.341212  1004.0
# product_name_lenght         45482.0     48.641441     10.163675     5.0
# product_description_lenght  45482.0    758.622224    648.566998     4.0
# product_photos_qty          45482.0      2.251286      1.728061     1.0
# product_weight_g            45481.0   2198.486137   3940.184440    50.0
# product_length_cm           45481.0     31.041204     16.348004     7.0
# product_height_cm           45481.0     16.890724     13.792866     2.0
# product_width_cm            45481.0     23.832172     12.206219     6.0
# seller_zip_code_prefix      45482.0  24868.556132  27531.128175  1001.0
# Year                        45482.0   2017.000000      0.000000  2017.0
# Month                       45482.0      7.969504      3.115559     1.0
# order_item_qty              45482.0      1.208082      0.703775     1.0
# product_qty                 45482.0      1.106855      0.467935     1.0
#
#                                  25%       50%       75%      max
# price                          40.00     76.90    139.00   6735.0
# freight_value                  13.43     16.11     20.19    314.4
# customer_zip_code_prefix    12248.00  26255.00  60540.75  99980.0
# product_name_lenght            42.00     52.00     57.00     72.0
# product_description_lenght    338.00    575.00    955.00   3992.0
# product_photos_qty              1.00      2.00      3.00     18.0
# product_weight_g              300.00    760.00   1850.00  40425.0
# product_length_cm              19.00     26.00     40.00    105.0
# product_height_cm               8.00     13.00     21.00    105.0
# product_width_cm               15.00     20.00     30.00    118.0
# seller_zip_code_prefix       7112.00  14050.00  31030.00  99700.0
# Year                         2017.00   2017.00   2017.00   2017.0
# Month                           6.00      8.00     11.00     12.0
# order_item_qty                  1.00      1.00      1.00     22.0
# product_qty                     1.00      1.00      1.00     20.0

# %% [markdown]
# #### 2017 Sales Trend

# %%
total_sales = orders17.groupby(by='Month')["price"].sum()
total_qty = orders17.groupby(by='Month')["order_item_qty"].sum()
revenue_per_item = (orders17.groupby(by='Month')["price"].sum()/ orders17.groupby(by='Month')["order_item_qty"].sum()).round(2)
order_size = (orders17.groupby(by='Month')["order_item_qty"].sum()/orders17.groupby(by='Month')["order_id"].nunique()).round(2)

sales = pd.DataFrame(
    {'Total_Sales': total_sales,
     'Total_Qty': total_qty,
     'Revenue_per_Item': revenue_per_item,
     'Order_Size': order_size})
sales
# Out:
#        Total_Sales  Total_Qty  Revenue_per_Item  Order_Size
# Month
# 1        108993.76       1076            101.30        1.38
# 2        225717.04       2062            109.47        1.23
# 3        347785.80       3173            109.61        1.23
# 4        330112.01       2791            118.28        1.20
# 5        466682.54       4418            105.63        1.24
# 6        410561.56       3853            106.56        1.22
# 7        464571.42       4957             93.72        1.27
# 8        532778.64       5317            100.20        1.26
# 9        567146.02       5159            109.93        1.23
# 10       599477.02       5918            101.30        1.31
# 11       922495.96       9524             96.86        1.30
# 12       691735.55       6698            103.27        1.22

# %%
x_values = sales.index.to_list()
y_values = sales['Total_Sales'].values
fig, ax = plt.subplots(figsize=(5, 2))
ax.plot(x_values, y_values, marker='o', linestyle='-', color='r')
ax.set_xticks(range(1, 13))
ax.set(title="2017 Sales($) Trend")
plt.show()

# %% [markdown]
# #### 2017 Sales Trend by product category

# %%
product = pd.DataFrame(orders17.groupby(by=['Month',"product_category_name_english"])['order_item_qty'].sum().round(3))
product = product.reset_index()
product = product.pivot(index = 'product_category_name_english', columns = 'Month', values = 'order_item_qty')
product['Total'] = product.sum(axis=1)
product.sort_values(by="Total", ascending=False)
# Out:
# Month                                      1      2      3      4      5  \
# product_category_name_english
# bed_bath_table                          52.0  183.0  342.0  318.0  412.0
# furniture_decor                        236.0  319.0  391.0  223.0  356.0
# sports_leisure                         118.0  164.0  211.0  228.0  339.0
# health_beauty                           85.0  179.0  219.0  197.0  305.0
# computers_accessories                   31.0  108.0  174.0  137.0  359.0
# ...                                      ...    ...    ...    ...    ...
# fashion_childrens_clothes                NaN    NaN    NaN    NaN    1.0
# small_appliances_home_oven_and_coffee    NaN    NaN    NaN    NaN    NaN
# arts_and_craftmanship                    NaN    NaN    NaN    NaN    2.0
# security_and_services                    1.0    NaN    NaN    NaN    NaN
# diapers_and_hygiene                      NaN    NaN    NaN    NaN    NaN
#
# Month                                      6      7      8      9     10  \
# product_category_name_english
# bed_bath_table                         481.0  708.0  593.0  627.0  819.0
# furniture_decor                        278.0  373.0  514.0  380.0  442.0
# sports_leisure                         295.0  409.0  446.0  479.0  497.0
# health_beauty                          273.0  369.0  383.0  397.0  382.0
# computers_accessories                  294.0  354.0  368.0  260.0  338.0
# ...                                      ...    ...    ...    ...    ...
# fashion_childrens_clothes                1.0    NaN    1.0    1.0    1.0
# small_appliances_home_oven_and_coffee    1.0    NaN    2.0    1.0    NaN
# arts_and_craftmanship                    NaN    1.0    NaN    NaN    NaN
# security_and_services                    NaN    NaN    NaN    1.0    NaN
# diapers_and_hygiene                      NaN    NaN    NaN    NaN    NaN
#
# Month                                      11     12   Total
# product_category_name_english
# bed_bath_table                         1217.0  660.0  6412.0
# furniture_decor                         933.0  436.0  4881.0
# sports_leisure                          632.0  539.0  4357.0
# health_beauty                           624.0  491.0  3904.0
# computers_accessories                   595.0  298.0  3316.0
# ...                                       ...    ...     ...
# fashion_childrens_clothes                 NaN    NaN     5.0
# small_appliances_home_oven_and_coffee     NaN    NaN     4.0
# arts_and_craftmanship                     NaN    NaN     3.0
# security_and_services                     NaN    NaN     2.0
# diapers_and_hygiene                       NaN    2.0     2.0
#
# [71 rows x 13 columns]

# %%
fig, axes = plt.subplots(18, 4, figsize=(10, 2 * 15))  # Creating a grid with 15 rows and 5 columns

for i in range(18):  # Iterate over rows
    for j in range(4):  # Iterate over columns
        idx = i * 5 + j  # Calculate the index for product data
        
        if idx < len(product):  # Check if within the range of available data
            x_values = product.columns.drop(['Total'])
            y_values = product.iloc[idx, :].drop(['Total'])

            axes[i, j].plot(x_values, y_values, marker='o', linestyle='-', color='r')
            axes[i, j].set_title(product.index[idx], fontsize=9)  # Adjust fontsize for title
            axes[i, j].grid(True)
            axes[i, j].set_xticks(range(1, len(x_values) + 1), fontsize = 8)  # Setting x-tick positions
            axes[i, j].set_xticklabels(x_values)  # Setting x-tick labels with rotation
        else:
            axes[i, j].axis('off')  # Turn off empty subplots if there's no data

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Product price chart

# %%
product17=orders17[['order_id','product_category_name_english','product_id', 'Month', 'order_item_qty', 'product_qty', 'price']]
product17
# Out:
#                                order_id product_category_name_english  \
# 0      e481f51cbdc54678b7cc49136f2d6af7                    housewares
# 1      6ea2f835b4556291ffdc53fa0b3b95e8                    housewares
# 2      82bce245b1c9148f8d19a55b9ff70644                    housewares
# 3      af5b0604e113e1526593d505a26ef39d                    housewares
# 4      1c35ac660d7ef6691b25d20df3d6eccb                    housewares
# ...                                 ...                           ...
# 45477  0d12f20556892f2a5aca4f39fb613a07                         music
# 45478  1b546846285271f61f42bf2954352172         arts_and_craftmanship
# 45479  9980064d9817bacc9e261e7f5fcf3fe5         arts_and_craftmanship
# 45480  2c4ada2e75c2ad41dd93cebb5df5f023         security_and_services
# 45481  bede3503afed051733eeb4a84d1adcc5         security_and_services
#
#                              product_id  Month  order_item_qty  product_qty  \
# 0      87285b34884572647811a353c7ac498a     10               1            1
# 1      be021417a6acb56b9b50d3fd2714baa8     11               1            1
# 2      a5a0e71a81ae65aa335e71c06261e260      4               5            5
# 3      978859c6048ded0fa8bf3b9ea8236387      9               1            1
# 4      42a2c92a0979a949ca4ea89ec5c7b934      6               1            1
# ...                                 ...    ...             ...          ...
# 45477  614a7083f3c1a64a1829fee6bc60d90d      3               1            1
# 45478  08c5c3d471845327e913b52aded0caf3      5               2            1
# 45479  ec90895370885d025efeb8e72e7fa699      7               1            1
# 45480  6c7a0a349ad11817745e3ad58abd5c79      1               1            1
# 45481  8db75af9aed3315374db44d7860e25da      9               1            1
#
#         price
# 0       29.99
# 1      339.00
# 2       38.00
# 3       19.90
# 4       59.90
# ...       ...
# 45477   27.99
# 45478   21.99
# 45479  129.90
# 45480  183.29
# 45481  100.00
#
# [45482 rows x 7 columns]

# %%
price_chart_1 = product17[product17['order_item_qty'] == 1][['product_id','Month','price']]
price_chart_1.sort_values('product_id').reset_index(drop=True).drop_duplicates()
# Out:
#                              product_id  Month   price
# 0      00088930e925c41fd95ebfe695fd2655     12  129.90
# 1      0009406fd7479715e4bef61dd91f2462     12  229.00
# 2      00126f27c813603687e6ce486d909d01      9  249.00
# 4      001795ec6f1b187d37335e1c4704762e     10   38.90
# 5      001795ec6f1b187d37335e1c4704762e     11   38.90
# ...                                 ...    ...     ...
# 39163  fff0a542c3c62682f23305214eaeaa24     12    7.50
# 39164  fff0a542c3c62682f23305214eaeaa24     11    7.30
# 39165  fff6177642830a9a94a0f2cba5e476d1      9  109.99
# 39166  fff6177642830a9a94a0f2cba5e476d1      7  119.99
# 39167  fff9553ac224cec9d15d49f5a263411f     10   32.00
#
# [25537 rows x 3 columns]

# %%
product17[(product17['order_item_qty'] != 1) & (product17['order_item_qty'] == product17['product_qty'])]
# Out:
#                                order_id product_category_name_english  \
# 2      82bce245b1c9148f8d19a55b9ff70644                    housewares
# 33     3d4a36b2720a815f829c5e1f82bbd0d5                    housewares
# 42     649119592692c2ce73021844e7892aa6                    housewares
# 81     9167e0a67d886b453dbb9318f1db42cc                    housewares
# 82     f99c42cf20b64fe3dc045ae83e56f4e1                    housewares
# ...                                 ...                           ...
# 45421  bf8335c7f470714a6a72b83d1fd1796c        signaling_and_security
# 45427  1001fec33bc88a484d7431bec2147348        signaling_and_security
# 45429  9bad30acdfaeb94d3ad6ac40d5cdff7b        signaling_and_security
# 45430  bacfb12b369a42b37e0246c786bf4637        signaling_and_security
# 45445  b144e2ac9863ed27bc59dbe4dd2f8773           diapers_and_hygiene
#
#                              product_id  Month  order_item_qty  product_qty  \
# 2      a5a0e71a81ae65aa335e71c06261e260      4               5            5
# 33     318fda70a35e94c586339fe51eafbe7d     11               3            3
# 42     c2a1ff8408a1c857c8730e4d12da714e      6               2            2
# 81     76be7b20bf23f866fd105deee7b205c6      6               2            2
# 82     f3ce47ccf98da2906f6b8b1387618e07      7               4            4
# ...                                 ...    ...             ...          ...
# 45421  0c8b6b6e4f9ee5fe2c48d6cee4c69bc8     11               3            3
# 45427  b655ebf10fa7727c97d82cffcfe96ab9      9               5            5
# 45429  fd40f3ef9c7fb9c550619a88af47a5de      5               2            2
# 45430  49e038a7b8ba2e18d9a7a26c1f238544      7               2            2
# 45445  f83fd2b539bc73678c65be8d418be8c1     12               2            2
#
#         price
# 2       38.00
# 33      22.66
# 42      69.90
# 81      37.00
# 82     120.00
# ...       ...
# 45421  118.00
# 45427    9.50
# 45429  214.00
# 45430  134.00
# 45445   38.00
#
# [3172 rows x 7 columns]

# %%
product17['per_item_price'] = round((product17['price']/product17['product_qty']),2)
# Out:
# C:\Users\JIYOON JUNG\AppData\Local\Temp\ipykernel_17528\1305004403.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   product17['per_item_price'] = round((product17['price']/product17['product_qty']),2)

# %%
product17[~product17['product_id'].isin(price_chart_1['product_id'])]
# Out:
#                                order_id product_category_name_english  \
# 23     ee038389c9f437f7c0e2d1b105a26038                    housewares
# 33     3d4a36b2720a815f829c5e1f82bbd0d5                    housewares
# 81     9167e0a67d886b453dbb9318f1db42cc                    housewares
# 94     ece1fa4a929c6a0e8b6678e10b2ac642                    housewares
# 112    e235f2f2440fa2abd4c0777a2fda1026                    housewares
# ...                                 ...                           ...
# 45448  80850824446cd379f755548b967c61b9                books_imported
# 45452  fb044859ae3cc0721c694443c343aed4                books_imported
# 45453  c6c7f7e01022b968655479b3f81b20ad                books_imported
# 45454  c6c7f7e01022b968655479b3f81b20ad                books_imported
# 45478  1b546846285271f61f42bf2954352172         arts_and_craftmanship
#
#                              product_id  Month  order_item_qty  product_qty  \
# 23     40c6502218c2b8ae624cd1576aac13c1      7               2            1
# 33     318fda70a35e94c586339fe51eafbe7d     11               3            3
# 81     76be7b20bf23f866fd105deee7b205c6      6               2            2
# 94     8ddbf2c953e42ed2a627c4ac08706bc2     11               2            1
# 112    dd735a55e6c75fb8fbe93e14d1c3bf07     10               2            1
# ...                                 ...    ...             ...          ...
# 45448  604f77463358e12a3154c65cf2c5d3d5      9               2            1
# 45452  f4c6e3643d47244bec4766d72c07ac4f     11               2            1
# 45453  f6c69d9a3f61a0d56c49e3f7a459c57f      6               2            1
# 45454  ac1edb0e0a6743cc20e6277ecfc1caf2      6               2            1
# 45478  08c5c3d471845327e913b52aded0caf3      5               2            1
#
#         price  per_item_price
# 23      59.00           59.00
# 33      22.66            7.55
# 81      37.00           18.50
# 94      98.00           98.00
# 112     26.90           26.90
# ...       ...             ...
# 45448  103.00          103.00
# 45452  109.00          109.00
# 45453   49.50           49.50
# 45454   49.50           49.50
# 45478   21.99           21.99
#
# [2096 rows x 8 columns]

# %%
price_chart_2= product17[~product17['product_id'].isin(price_chart_1['product_id'])][['product_id', 'Month', 'per_item_price']].rename(columns = {'per_item_price': 'price'})
price_chart_2
# Out:
#                              product_id  Month   price
# 23     40c6502218c2b8ae624cd1576aac13c1      7   59.00
# 33     318fda70a35e94c586339fe51eafbe7d     11    7.55
# 81     76be7b20bf23f866fd105deee7b205c6      6   18.50
# 94     8ddbf2c953e42ed2a627c4ac08706bc2     11   98.00
# 112    dd735a55e6c75fb8fbe93e14d1c3bf07     10   26.90
# ...                                 ...    ...     ...
# 45448  604f77463358e12a3154c65cf2c5d3d5      9  103.00
# 45452  f4c6e3643d47244bec4766d72c07ac4f     11  109.00
# 45453  f6c69d9a3f61a0d56c49e3f7a459c57f      6   49.50
# 45454  ac1edb0e0a6743cc20e6277ecfc1caf2      6   49.50
# 45478  08c5c3d471845327e913b52aded0caf3      5   21.99
#
# [2096 rows x 3 columns]

# %%
price_chart = pd.concat([price_chart_1, price_chart_2])
price_chart
# Out:
#                              product_id  Month   price
# 0      87285b34884572647811a353c7ac498a     10   29.99
# 1      be021417a6acb56b9b50d3fd2714baa8     11  339.00
# 3      978859c6048ded0fa8bf3b9ea8236387      9   19.90
# 4      42a2c92a0979a949ca4ea89ec5c7b934      6   59.90
# 5      28f2e74ecd7f12eab02ca9b3c2bd9c5f      3   87.37
# ...                                 ...    ...     ...
# 45448  604f77463358e12a3154c65cf2c5d3d5      9  103.00
# 45452  f4c6e3643d47244bec4766d72c07ac4f     11  109.00
# 45453  f6c69d9a3f61a0d56c49e3f7a459c57f      6   49.50
# 45454  ac1edb0e0a6743cc20e6277ecfc1caf2      6   49.50
# 45478  08c5c3d471845327e913b52aded0caf3      5   21.99
#
# [41264 rows x 3 columns]

# %%
product17[~((product17['product_id'].isin(price_chart['product_id']) & (product17['Month'].isin(price_chart['Month']))))]
# Out:
# Empty DataFrame
# Columns: [order_id, product_category_name_english, product_id, Month, order_item_qty, product_qty, price, per_item_price]
# Index: []
